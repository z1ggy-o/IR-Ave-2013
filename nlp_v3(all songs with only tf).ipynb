# %%
import pandas as pd

data = pd.read_csv('mylyrics00.csv')
singer = (list(set(list(data.iloc[:-1]['artist']))))
print(singer)

lyrics = []
for i in range(len(singer)):
    sing = singer[i]
    temp = ""
    #print(len(data.iloc[:-1]['lyrics']))
    for j in range(len(data.iloc[:-1]['lyrics'])):
        if sing == data.iloc[j]['artist']:
            #a = data.iloc[j]['lyrics'].split(' ')
            temp = temp + " " + data.iloc[j]['lyrics']
    lyrics.append(temp)
# Out:
# ['eminem', 'chris-brown', 'drake', 'beyonce-knowles', 'brad-paisley', 'coldplay', 'the-calling', 'bryan-adams', 'dr-dre', 'ed-sheeran', 'billy-ray-cyrus', 'glen-campbell', '2pac', 'eddy-arnold', 'beatles', 'garth-brooks', 'ciara', 'ariana-grande', 'ghostface-killah', '50-cent', 'the-doors']

# %%
print(lyrics[0])
# Out:
#  Ya look
# If I were to rap about the crap that's out
# That's the route you probably want me to take
# Cause your just dyeing to know what I think
# And my take on some other rappers
# If I was to say somethin' bout' Paul Wall
# You'd probably crap in your pants cause I'm white and he's white
# So he's like my competition I mean right
# Nope, Paul Wall is dope and so's Bubba
# But, but, But....
# But I don't compete wit nobody
# I just go hard do the rope a dope ali shuffle
# And dance around my opponents do donuts
# Sometimes I play possum like I'm asleep it's awesome!
# I'm like a sleeping giant and when I awake I'm like Dre
# I just jump from outta no where and bite prey
# And sink my teeth in and fill em' full a poison
# And make a noise like a snake before I kill em'
# And let em' know I just don't feel em'
# And smack em' with the backward E the' Eminem emblem
# I was taught if your gonna murder somebody you should face em'
# ...

# %%
print(len(lyrics[0]))
# Out:
# 2017456

# %%
#for i in range(len(lyrics)):
    #print(i)
#    lyrics[i] = str(lyrics[i]).split(' ')

# %%
from nltk.tokenize.regexp import regexp_tokenize


test_list = []
for i in range(len(lyrics)):
    list_a=[]
    temp=str(lyrics[i])
    temp=temp.lower()
    list_a=regexp_tokenize(temp, "[a-z]['a-z]*")
    test_list.append(list_a)

# %%
print(len(test_list))
# Out:
# 21

# %%
print(test_list[0])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk
#nltk.download('stopwords')
stopWords = list(set(stopwords.words('english')))
#print(stopWords)

for i in range(len(test_list)):
    temp = []
    #for j in range(len(lyrics[i])):
    for j in test_list[i]:
        #print(j)
        if j not in stopWords:
            temp.append(j)
            #print(temp)
    test_list[i] = temp

# %%
lyrics_term = []
for i in range(len(test_list)):
    temp = {}
    for j in range(len(test_list[i])):
        try:
            temp[test_list[i][j]] += 1
        except KeyError:
            temp[test_list[i][j]] = 1
    lyrics_term.append(temp)

# %%
all_term = []
for i in range(len(lyrics)):
    for j in range(len(test_list[i])):
        all_term.append(test_list[i][j])
all_term = set(all_term)
print(len(all_term))
# Out:
# 35455

# %%
all_lyrics_term = []
for i in range(len(lyrics_term)):
    temp = {}
    for j in all_term:
        try:
            temp[j] = lyrics_term[i][j]
        except KeyError:
            temp[j] = 0
    all_lyrics_term.append(temp)

# %%
a = {}
for i in range(len(singer)):
    a[singer[i]] = all_lyrics_term[i]

# %%
df = pd.DataFrame(a, columns=singer)

# %%
df
# Out:
#                     eminem  chris-brown  drake  beyonce-knowles  brad-paisley  \
# a'                       3            0      1                0             0
# a'ight                   4            0      0                0             0
# a'int                    0            0      3                0             0
# a'moving                 0            0      0                0             0
# a'rattlin'               0            0      0                0             0
# a'ringing                0            0      0                0             0
# a's                      1            4      1                0             0
# a'ticking                0            0      0                0             0
# a'waitin'                0            0      0                0             0
# aa                       0            0      0                0             0
# aaa                      0            0      0                0             0
# ...

# %%
term = list(df.T.columns)

# %%
a = df.T
a
# Out:
#                   a'  a'ight  a'int  a'moving  a'rattlin'  a'ringing  a's  \
# eminem             3       4      0         0           0          0    1
# chris-brown        0       0      0         0           0          0    4
# drake              1       0      3         0           0          0    1
# beyonce-knowles    0       0      0         0           0          0    0
# brad-paisley       0       0      0         0           0          0    0
# coldplay           0       0      0         0           0          1    0
# the-calling        0       0      0         0           0          0    0
# bryan-adams        1       0      0         0           0          0    0
# dr-dre             0       0      0         0           0          0    0
# ed-sheeran         0       0      0         0           0          0    0
# billy-ray-cyrus    2       0      0         0           0          0    0
# glen-campbell      0       0      0         0           0          0    0
# ...

# %%
print(term)
# Out:
# ["a'", "a'ight", "a'int", "a'moving", "a'rattlin'", "a'ringing", "a's", "a'ticking", "a'waitin'", 'aa', 'aaa', 'aaaa', 'aaaaa', 'aaaaaa', 'aaaaaaaaa', 'aaaaaaaahhhh', 'aaaaaaahhhh', 'aaaaaaahhhhhhhh', 'aaaaaah', 'aaaaaahhhhhh', 'aaaaaalright', 'aaaaaamen', 'aaaaah', 'aaaaahhhhhhhhhhhhh', 'aaaah', 'aaaahhhhhh', 'aaaallll', 'aaaare', 'aaah', 'aaahhh', 'aaahhhh', 'aaall', 'aaaww', 'aae', 'aah', "aah's", 'aahh', 'aahhh', 'aahhhh', 'aahm', 'aaliyah', "aaliyah's", 'aaron', 'aat', 'aaw', 'ab', 'aba', 'aback', 'abandoned', 'abbott', 'abbreviato', 'abc', "abc's", 'abcdefghijklmnopqrstuvwxy', 'abcs', 'abdomen', 'abdrul', 'abducted', 'abduction', 'abdul', 'abdullah', 'abe', 'abel', 'abiddout', 'abide', 'abided', 'abiding', 'abilities', 'ability', 'ablaze', 'able', 'ables', 'ablige', 'aboard', 'aborning', 'abort', 'aborted', 'abortion', 'abortions', 'abou', 'abounding', "about'", 'abouton', 'abracadabra', 'abraf', 'abraham', 'abrasive', 'abroad', 'abruptly', 'abs', 'abscence', 'absence', 'absent
# ...

# %%
from tqdm import tqdm_notebook
count2 = 0
for i in tqdm_notebook(term):
    count = 0
    #print(i)
    #print(a.iloc[j][i])
    #print(count)
    for j in range(len(singer)):
        if a.iloc[j][i] != 0:
            count += 1
    #print(count)
    if count > (len(singer) / 2):
        #print(i)
        count2 += 1
        a.drop_duplicates(i, keep=False)

# %%
a
# Out:
#                   a'  a'ight  a'int  a'moving  a'rattlin'  a'ringing  a's  \
# eminem             3       4      0         0           0          0    1
# chris-brown        0       0      0         0           0          0    4
# drake              1       0      3         0           0          0    1
# beyonce-knowles    0       0      0         0           0          0    0
# brad-paisley       0       0      0         0           0          0    0
# coldplay           0       0      0         0           0          1    0
# the-calling        0       0      0         0           0          0    0
# bryan-adams        1       0      0         0           0          0    0
# dr-dre             0       0      0         0           0          0    0
# ed-sheeran         0       0      0         0           0          0    0
# billy-ray-cyrus    2       0      0         0           0          0    0
# glen-campbell      0       0      0         0           0          0    0
# ...

# %%
from numpy import dot
from numpy.linalg import norm
import numpy as np
def cos_sim(A, B):
       return round(dot(A, B)/(norm(A)*norm(B)), 3)

# %%
a = a.T
a
word_list=list(a.columns)

# %%
from operator import itemgetter
ciara_a=[]
eminem_a = []
for i in range(len(a.iloc[0])):
    ciara_a.append([a.iloc[0][i],word_list[i]])
    eminem_a.append([a.iloc[1][i],word_list[i]])
ciara_a.sort(key=itemgetter(0),reverse=True)
eminem_a.sort(key=itemgetter(0),reverse=True)
b = np.asarray(a.iloc[:]['ciara'])
c = np.asarray(a.iloc[:]['eminem'])

# %%
print(ciara_a)
# Out:
# [[3, 'eminem'], [3, 'ciara'], [2, 'billy-ray-cyrus'], [1, 'drake'], [1, 'bryan-adams'], [1, '50-cent'], [0, 'chris-brown'], [0, 'beyonce-knowles'], [0, 'brad-paisley'], [0, 'coldplay'], [0, 'the-calling'], [0, 'dr-dre'], [0, 'ed-sheeran'], [0, 'glen-campbell'], [0, '2pac'], [0, 'eddy-arnold'], [0, 'beatles'], [0, 'garth-brooks'], [0, 'ariana-grande'], [0, 'ghostface-killah'], [0, 'the-doors']]

# %%
print(eminem_a)
# Out:
# [[4, 'eminem'], [1, '50-cent'], [0, 'chris-brown'], [0, 'drake'], [0, 'beyonce-knowles'], [0, 'brad-paisley'], [0, 'coldplay'], [0, 'the-calling'], [0, 'bryan-adams'], [0, 'dr-dre'], [0, 'ed-sheeran'], [0, 'billy-ray-cyrus'], [0, 'glen-campbell'], [0, '2pac'], [0, 'eddy-arnold'], [0, 'beatles'], [0, 'garth-brooks'], [0, 'ciara'], [0, 'ariana-grande'], [0, 'ghostface-killah'], [0, 'the-doors']]

# %%
aaa = []
for i in range(len(singer)):
    aaa.append(np.asarray(a.iloc[:][singer[i]]))

# %%
cos_sim_a=[]

for i in range(len(singer)):
    list_sim=[]
    for j in range(len(singer)):
        list_sim.append(cos_sim(aaa[i],aaa[j]))
  
    cos_sim_a.append(list_sim)
for i in range(len(singer)):
    print(cos_sim_a[i])
# Out:
# [1.0, 0.819, 0.919, 0.779, 0.793, 0.66, 0.672, 0.717, 0.893, 0.753, 0.732, 0.681, 0.849, 0.635, 0.686, 0.743, 0.817, 0.666, 0.856, 0.892, 0.607]
# [0.819, 1.0, 0.888, 0.878, 0.784, 0.71, 0.68, 0.802, 0.791, 0.77, 0.761, 0.718, 0.769, 0.68, 0.814, 0.732, 0.886, 0.814, 0.778, 0.813, 0.696]
# [0.919, 0.888, 1.0, 0.808, 0.806, 0.675, 0.699, 0.759, 0.883, 0.765, 0.753, 0.707, 0.849, 0.657, 0.755, 0.742, 0.846, 0.723, 0.853, 0.901, 0.657]
# [0.779, 0.878, 0.808, 1.0, 0.793, 0.773, 0.71, 0.811, 0.696, 0.837, 0.806, 0.789, 0.721, 0.785, 0.85, 0.769, 0.874, 0.856, 0.705, 0.717, 0.711]
# [0.793, 0.784, 0.806, 0.793, 1.0, 0.748, 0.764, 0.837, 0.708, 0.772, 0.871, 0.835, 0.733, 0.809, 0.815, 0.874, 0.767, 0.73, 0.736, 0.697, 0.747]
# [0.66, 0.71, 0.675, 0.773, 0.748, 1.0, 0.755, 0.785, 0.578, 0.728, 0.732, 0.743, 0.602, 0.723, 0.792, 0.748, 0.681, 0.685, 0.566, 0.576, 0.663]
# ...

# %% [markdown]
# # Max accuracy

# %%
for i in range(len(cos_sim_a)):
    test = cos_sim_a[i][:]
    test.pop(test.index(max(test)))
    a = cos_sim_a[i].index(max(test))
    print("" + singer[i] +"      "  + singer[a]+ " :   " + str(max(test)))
# Out:
# eminem      drake :   0.919
# chris-brown      drake :   0.888
# drake      eminem :   0.919
# beyonce-knowles      chris-brown :   0.878
# brad-paisley      garth-brooks :   0.874
# coldplay      beatles :   0.792
# the-calling      bryan-adams :   0.784
# bryan-adams      brad-paisley :   0.837
# dr-dre      50-cent :   0.915
# ed-sheeran      beyonce-knowles :   0.837
# billy-ray-cyrus      glen-campbell :   0.88
# glen-campbell      eddy-arnold :   0.916
# 2pac      dr-dre :   0.89
# eddy-arnold      glen-campbell :   0.916
# beatles      beyonce-knowles :   0.85
# garth-brooks      brad-paisley :   0.874
# ciara      chris-brown :   0.886
# ariana-grande      beyonce-knowles :   0.856
# ghostface-killah      dr-dre :   0.878
# 50-cent      dr-dre :   0.915
# the-doors      beatles :   0.801

# %% [markdown]
# # Min accuracy

# %%
for i in range(len(cos_sim_a)):
    a = cos_sim_a[i].index(min(cos_sim_a[i]))
    print("" + singer[i] +"/"  + singer[a]+ " :   " + str(min(cos_sim_a[i])))
# Out:
# eminem/the-doors :   0.607
# chris-brown/the-calling :   0.68
# drake/eddy-arnold :   0.657
# beyonce-knowles/dr-dre :   0.696
# brad-paisley/50-cent :   0.697
# coldplay/ghostface-killah :   0.566
# the-calling/ghostface-killah :   0.568
# bryan-adams/ghostface-killah :   0.648
# dr-dre/eddy-arnold :   0.541
# ed-sheeran/dr-dre :   0.655
# billy-ray-cyrus/50-cent :   0.64
# glen-campbell/50-cent :   0.586
# 2pac/coldplay :   0.602
# eddy-arnold/dr-dre :   0.541
# beatles/dr-dre :   0.616
# garth-brooks/50-cent :   0.634
# ciara/the-calling :   0.674
# ariana-grande/ghostface-killah :   0.6
# ghostface-killah/coldplay :   0.566
# 50-cent/eddy-arnold :   0.541
# the-doors/dr-dre :   0.571
